# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from google.colab import files
uploaded = files.upload()
filename = list(uploaded.keys())[0]
filename
# Out:
#      <input type="file" id="files-89469435-d8b7-4742-8e79-2f566e30520b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89469435-d8b7-4742-8e79-2f566e30520b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sonar.csv to sonar.csv
# 'sonar.csv'

# %%
df = pd.read_csv(filename, header=None)
df.head()
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
#  20  20      208 non-null    float64
#  21  21      208 non-null    float64
#  22  22      208 non-null    float64
#  23  23      208 non-null    float64
#  24  24      208 non-null    float64
#  25  25      208 non-null    float64
#  26  26      208 non-null    float64
#  27  27      208 non-null    float64
#  28  28      208 non-null    float64
#  29  29      208 non-null    float64
#  30  30      208 non-null    float64
#  31  31      208 non-null    float64
#  32  32      208 non-null    float64
#  33  33      208 non-null    float64
#  34  34      208 non-null    float64
#  35  35      208 non-null    float64
#  36  36      208 non-null    float64
#  37  37      208 non-null    float64
#  38  38      208 non-null    float64
#  39  39      208 non-null    float64
#  40  40      208 non-null    float64
#  41  41      208 non-null    float64
#  42  42      208 non-null    float64
#  43  43      208 non-null    float64
#  44  44      208 non-null    float64
#  45  45      208 non-null    float64
#  46  46      208 non-null    float64
#  47  47      208 non-null    float64
#  48  48      208 non-null    float64
#  49  49      208 non-null    float64
#  50  50      208 non-null    float64
#  51  51      208 non-null    float64
#  52  52      208 non-null    float64
#  53  53      208 non-null    float64
#  54  54      208 non-null    float64
#  55  55      208 non-null    float64
#  56  56      208 non-null    float64
#  57  57      208 non-null    float64
#  58  58      208 non-null    float64
#  59  59      208 non-null    float64
#  60  60      208 non-null    object
# dtypes: float64(60), object(1)
# memory usage: 99.2+ KB

# %%
df.describe()
# Out:
#                0           1           2   ...          57          58          59
# count  208.000000  208.000000  208.000000  ...  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832  ...    0.007949    0.007941    0.006507
# std      0.022991    0.032960    0.038428  ...    0.006470    0.006181    0.005031
# min      0.001500    0.000600    0.001500  ...    0.000300    0.000100    0.000600
# 25%      0.013350    0.016450    0.018950  ...    0.003600    0.003675    0.003100
# 50%      0.022800    0.030800    0.034300  ...    0.005800    0.006400    0.005300
# 75%      0.035550    0.047950    0.057950  ...    0.010350    0.010325    0.008525
# max      0.137100    0.233900    0.305900  ...    0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X = df.iloc[:, :-1].values
y_encoded = le.fit_transform(df[60].values)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, stratify=y_encoded, random_state=seed)
X_train.shape, X_test.shape
# Out:
# ((156, 60), (52, 60))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([
                    Dense(24, input_dim=60, activation='relu'),
                    Dense(8, activation='relu'),
                    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 24)                1464
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 200
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,673
# Trainable params: 1,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
import os
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
  os.mkdir(MODEL_DIR)
modelpath = MODEL_DIR + 'best{epoch:03d}-{val_loss:.4f}.hdf5'

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=30)

# %%
history = model.fit(X_train, y_train, validation_split=0.2, epochs=500, batch_size=200, verbose=0, callbacks=[checkpointer, early_stopping])
# Out:
# Epoch 00001: val_loss improved from inf to 0.69486, saving model to ./model/best001-0.6949.hdf5
#
# Epoch 00002: val_loss improved from 0.69486 to 0.69260, saving model to ./model/best002-0.6926.hdf5
#
# Epoch 00003: val_loss improved from 0.69260 to 0.69148, saving model to ./model/best003-0.6915.hdf5
#
# Epoch 00004: val_loss improved from 0.69148 to 0.69020, saving model to ./model/best004-0.6902.hdf5
#
# Epoch 00005: val_loss improved from 0.69020 to 0.68854, saving model to ./model/best005-0.6885.hdf5
#
# Epoch 00006: val_loss improved from 0.68854 to 0.68796, saving model to ./model/best006-0.6880.hdf5
#
# Epoch 00007: val_loss improved from 0.68796 to 0.68768, saving model to ./model/best007-0.6877.hdf5
#
# Epoch 00008: val_loss improved from 0.68768 to 0.68733, saving model to ./model/best008-0.6873.hdf5
#
# Epoch 00009: val_loss improved from 0.68733 to 0.68709, saving model to ./model/best009-0.6871.hdf5
#
# Epoch 00010: val_loss improved from 0.68709 to 0.68635, saving model to ./model/best010-0.6864.hdf5
#
# Epoch 00011: val_loss improved from 0.68635 to 0.68468, saving model to ./model/best011-0.6847.hdf5
#
# Epoch 00012: val_loss improved from 0.68468 to 0.68278, saving model to ./model/best012-0.6828.hdf5
#
# Epoch 00013: val_loss improved from 0.68278 to 0.68069, saving model to ./model/best013-0.6807.hdf5
#
# Epoch 00014: val_loss improved from 0.68069 to 0.67838, saving model to ./model/best014-0.6784.hdf5
#
# Epoch 00015: val_loss improved from 0.67838 to 0.67596, saving model to ./model/best015-0.6760.hdf5
#
# Epoch 00016: val_loss improved from 0.67596 to 0.67327, saving model to ./model/best016-0.6733.hdf5
#
# Epoch 00017: val_loss improved from 0.67327 to 0.67042, saving model to ./model/best017-0.6704.hdf5
#
# Epoch 00018: val_loss improved from 0.67042 to 0.66720, saving model to ./model/best018-0.6672.hdf5
#
# Epoch 00019: val_loss improved from 0.66720 to 0.66417, saving model to ./model/best019-0.6642.hdf5
#
# Epoch 00020: val_loss improved from 0.66417 to 0.66131, saving model to ./model/best020-0.6613.hdf5
#
# Epoch 00021: val_loss improved from 0.66131 to 0.65902, saving model to ./model/best021-0.6590.hdf5
#
# Epoch 00022: val_loss improved from 0.65902 to 0.65673, saving model to ./model/best022-0.6567.hdf5
#
# Epoch 00023: val_loss improved from 0.65673 to 0.65468, saving model to ./model/best023-0.6547.hdf5
#
# Epoch 00024: val_loss improved from 0.65468 to 0.65277, saving model to ./model/best024-0.6528.hdf5
#
# Epoch 00025: val_loss improved from 0.65277 to 0.65092, saving model to ./model/best025-0.6509.hdf5
#
# Epoch 00026: val_loss improved from 0.65092 to 0.64915, saving model to ./model/best026-0.6491.hdf5
#
# Epoch 00027: val_loss improved from 0.64915 to 0.64750, saving model to ./model/best027-0.6475.hdf5
#
# Epoch 00028: val_loss improved from 0.64750 to 0.64588, saving model to ./model/best028-0.6459.hdf5
#
# Epoch 00029: val_loss improved from 0.64588 to 0.64438, saving model to ./model/best029-0.6444.hdf5
#
# Epoch 00030: val_loss improved from 0.64438 to 0.64265, saving model to ./model/best030-0.6427.hdf5
#
# Epoch 00031: val_loss improved from 0.64265 to 0.64089, saving model to ./model/best031-0.6409.hdf5
#
# Epoch 00032: val_loss improved from 0.64089 to 0.63920, saving model to ./model/best032-0.6392.hdf5
#
# Epoch 00033: val_loss improved from 0.63920 to 0.63758, saving model to ./model/best033-0.6376.hdf5
#
# Epoch 00034: val_loss improved from 0.63758 to 0.63605, saving model to ./model/best034-0.6360.hdf5
#
# Epoch 00035: val_loss improved from 0.63605 to 0.63474, saving model to ./model/best035-0.6347.hdf5
#
# Epoch 00036: val_loss improved from 0.63474 to 0.63335, saving model to ./model/best036-0.6334.hdf5
#
# Epoch 00037: val_loss improved from 0.63335 to 0.63192, saving model to ./model/best037-0.6319.hdf5
#
# Epoch 00038: val_loss improved from 0.63192 to 0.63045, saving model to ./model/best038-0.6304.hdf5
#
# Epoch 00039: val_loss improved from 0.63045 to 0.62904, saving model to ./model/best039-0.6290.hdf5
#
# Epoch 00040: val_loss improved from 0.62904 to 0.62762, saving model to ./model/best040-0.6276.hdf5
#
# Epoch 00041: val_loss improved from 0.62762 to 0.62614, saving model to ./model/best041-0.6261.hdf5
#
# Epoch 00042: val_loss improved from 0.62614 to 0.62468, saving model to ./model/best042-0.6247.hdf5
#
# Epoch 00043: val_loss improved from 0.62468 to 0.62312, saving model to ./model/best043-0.6231.hdf5
#
# Epoch 00044: val_loss improved from 0.62312 to 0.62133, saving model to ./model/best044-0.6213.hdf5
#
# Epoch 00045: val_loss improved from 0.62133 to 0.61936, saving model to ./model/best045-0.6194.hdf5
#
# Epoch 00046: val_loss improved from 0.61936 to 0.61726, saving model to ./model/best046-0.6173.hdf5
#
# Epoch 00047: val_loss improved from 0.61726 to 0.61504, saving model to ./model/best047-0.6150.hdf5
#
# Epoch 00048: val_loss improved from 0.61504 to 0.61270, saving model to ./model/best048-0.6127.hdf5
#
# Epoch 00049: val_loss improved from 0.61270 to 0.61050, saving model to ./model/best049-0.6105.hdf5
#
# Epoch 00050: val_loss improved from 0.61050 to 0.60836, saving model to ./model/best050-0.6084.hdf5
#
# Epoch 00051: val_loss improved from 0.60836 to 0.60627, saving model to ./model/best051-0.6063.hdf5
#
# Epoch 00052: val_loss improved from 0.60627 to 0.60415, saving model to ./model/best052-0.6042.hdf5
#
# Epoch 00053: val_loss improved from 0.60415 to 0.60199, saving model to ./model/best053-0.6020.hdf5
#
# Epoch 00054: val_loss improved from 0.60199 to 0.59981, saving model to ./model/best054-0.5998.hdf5
#
# Epoch 00055: val_loss improved from 0.59981 to 0.59773, saving model to ./model/best055-0.5977.hdf5
#
# Epoch 00056: val_loss improved from 0.59773 to 0.59565, saving model to ./model/best056-0.5956.hdf5
#
# Epoch 00057: val_loss improved from 0.59565 to 0.59348, saving model to ./model/best057-0.5935.hdf5
#
# Epoch 00058: val_loss improved from 0.59348 to 0.59117, saving model to ./model/best058-0.5912.hdf5
#
# Epoch 00059: val_loss improved from 0.59117 to 0.58869, saving model to ./model/best059-0.5887.hdf5
#
# Epoch 00060: val_loss improved from 0.58869 to 0.58598, saving model to ./model/best060-0.5860.hdf5
#
# Epoch 00061: val_loss improved from 0.58598 to 0.58322, saving model to ./model/best061-0.5832.hdf5
#
# Epoch 00062: val_loss improved from 0.58322 to 0.58063, saving model to ./model/best062-0.5806.hdf5
#
# Epoch 00063: val_loss improved from 0.58063 to 0.57808, saving model to ./model/best063-0.5781.hdf5
#
# Epoch 00064: val_loss improved from 0.57808 to 0.57558, saving model to ./model/best064-0.5756.hdf5
#
# Epoch 00065: val_loss improved from 0.57558 to 0.57315, saving model to ./model/best065-0.5732.hdf5
#
# Epoch 00066: val_loss improved from 0.57315 to 0.57078, saving model to ./model/best066-0.5708.hdf5
#
# Epoch 00067: val_loss improved from 0.57078 to 0.56836, saving model to ./model/best067-0.5684.hdf5
#
# Epoch 00068: val_loss improved from 0.56836 to 0.56593, saving model to ./model/best068-0.5659.hdf5
#
# Epoch 00069: val_loss improved from 0.56593 to 0.56340, saving model to ./model/best069-0.5634.hdf5
#
# Epoch 00070: val_loss improved from 0.56340 to 0.56090, saving model to ./model/best070-0.5609.hdf5
#
# Epoch 00071: val_loss improved from 0.56090 to 0.55841, saving model to ./model/best071-0.5584.hdf5
#
# Epoch 00072: val_loss improved from 0.55841 to 0.55588, saving model to ./model/best072-0.5559.hdf5
#
# Epoch 00073: val_loss improved from 0.55588 to 0.55339, saving model to ./model/best073-0.5534.hdf5
#
# Epoch 00074: val_loss improved from 0.55339 to 0.55096, saving model to ./model/best074-0.5510.hdf5
#
# Epoch 00075: val_loss improved from 0.55096 to 0.54860, saving model to ./model/best075-0.5486.hdf5
#
# Epoch 00076: val_loss improved from 0.54860 to 0.54635, saving model to ./model/best076-0.5464.hdf5
#
# Epoch 00077: val_loss improved from 0.54635 to 0.54413, saving model to ./model/best077-0.5441.hdf5
#
# Epoch 00078: val_loss improved from 0.54413 to 0.54192, saving model to ./model/best078-0.5419.hdf5
#
# Epoch 00079: val_loss improved from 0.54192 to 0.53986, saving model to ./model/best079-0.5399.hdf5
#
# Epoch 00080: val_loss improved from 0.53986 to 0.53792, saving model to ./model/best080-0.5379.hdf5
#
# Epoch 00081: val_loss improved from 0.53792 to 0.53613, saving model to ./model/best081-0.5361.hdf5
#
# Epoch 00082: val_loss improved from 0.53613 to 0.53451, saving model to ./model/best082-0.5345.hdf5
#
# Epoch 00083: val_loss improved from 0.53451 to 0.53293, saving model to ./model/best083-0.5329.hdf5
#
# Epoch 00084: val_loss improved from 0.53293 to 0.53118, saving model to ./model/best084-0.5312.hdf5
#
# Epoch 00085: val_loss improved from 0.53118 to 0.52947, saving model to ./model/best085-0.5295.hdf5
#
# Epoch 00086: val_loss improved from 0.52947 to 0.52783, saving model to ./model/best086-0.5278.hdf5
#
# Epoch 00087: val_loss improved from 0.52783 to 0.52615, saving model to ./model/best087-0.5261.hdf5
#
# Epoch 00088: val_loss improved from 0.52615 to 0.52448, saving model to ./model/best088-0.5245.hdf5
#
# Epoch 00089: val_loss improved from 0.52448 to 0.52277, saving model to ./model/best089-0.5228.hdf5
#
# Epoch 00090: val_loss improved from 0.52277 to 0.52103, saving model to ./model/best090-0.5210.hdf5
#
# Epoch 00091: val_loss improved from 0.52103 to 0.51917, saving model to ./model/best091-0.5192.hdf5
#
# Epoch 00092: val_loss improved from 0.51917 to 0.51712, saving model to ./model/best092-0.5171.hdf5
#
# Epoch 00093: val_loss improved from 0.51712 to 0.51507, saving model to ./model/best093-0.5151.hdf5
#
# Epoch 00094: val_loss improved from 0.51507 to 0.51308, saving model to ./model/best094-0.5131.hdf5
#
# Epoch 00095: val_loss improved from 0.51308 to 0.51138, saving model to ./model/best095-0.5114.hdf5
#
# Epoch 00096: val_loss improved from 0.51138 to 0.50973, saving model to ./model/best096-0.5097.hdf5
#
# Epoch 00097: val_loss improved from 0.50973 to 0.50806, saving model to ./model/best097-0.5081.hdf5
#
# Epoch 00098: val_loss improved from 0.50806 to 0.50617, saving model to ./model/best098-0.5062.hdf5
#
# Epoch 00099: val_loss improved from 0.50617 to 0.50408, saving model to ./model/best099-0.5041.hdf5
#
# Epoch 00100: val_loss improved from 0.50408 to 0.50198, saving model to ./model/best100-0.5020.hdf5
#
# Epoch 00101: val_loss improved from 0.50198 to 0.49996, saving model to ./model/best101-0.5000.hdf5
#
# Epoch 00102: val_loss improved from 0.49996 to 0.49797, saving model to ./model/best102-0.4980.hdf5
#
# Epoch 00103: val_loss improved from 0.49797 to 0.49620, saving model to ./model/best103-0.4962.hdf5
#
# Epoch 00104: val_loss improved from 0.49620 to 0.49428, saving model to ./model/best104-0.4943.hdf5
#
# Epoch 00105: val_loss improved from 0.49428 to 0.49206, saving model to ./model/best105-0.4921.hdf5
#
# Epoch 00106: val_loss improved from 0.49206 to 0.48960, saving model to ./model/best106-0.4896.hdf5
#
# Epoch 00107: val_loss improved from 0.48960 to 0.48706, saving model to ./model/best107-0.4871.hdf5
#
# Epoch 00108: val_loss improved from 0.48706 to 0.48449, saving model to ./model/best108-0.4845.hdf5
#
# Epoch 00109: val_loss improved from 0.48449 to 0.48195, saving model to ./model/best109-0.4820.hdf5
#
# Epoch 00110: val_loss improved from 0.48195 to 0.47946, saving model to ./model/best110-0.4795.hdf5
#
# Epoch 00111: val_loss improved from 0.47946 to 0.47713, saving model to ./model/best111-0.4771.hdf5
#
# Epoch 00112: val_loss improved from 0.47713 to 0.47492, saving model to ./model/best112-0.4749.hdf5
#
# Epoch 00113: val_loss improved from 0.47492 to 0.47270, saving model to ./model/best113-0.4727.hdf5
#
# Epoch 00114: val_loss improved from 0.47270 to 0.47075, saving model to ./model/best114-0.4708.hdf5
#
# Epoch 00115: val_loss improved from 0.47075 to 0.46898, saving model to ./model/best115-0.4690.hdf5
#
# Epoch 00116: val_loss improved from 0.46898 to 0.46734, saving model to ./model/best116-0.4673.hdf5
#
# Epoch 00117: val_loss improved from 0.46734 to 0.46570, saving model to ./model/best117-0.4657.hdf5
#
# Epoch 00118: val_loss improved from 0.46570 to 0.46412, saving model to ./model/best118-0.4641.hdf5
#
# Epoch 00119: val_loss improved from 0.46412 to 0.46253, saving model to ./model/best119-0.4625.hdf5
#
# Epoch 00120: val_loss improved from 0.46253 to 0.46096, saving model to ./model/best120-0.4610.hdf5
#
# Epoch 00121: val_loss improved from 0.46096 to 0.45935, saving model to ./model/best121-0.4594.hdf5
#
# Epoch 00122: val_loss improved from 0.45935 to 0.45786, saving model to ./model/best122-0.4579.hdf5
#
# Epoch 00123: val_loss improved from 0.45786 to 0.45651, saving model to ./model/best123-0.4565.hdf5
#
# Epoch 00124: val_loss improved from 0.45651 to 0.45541, saving model to ./model/best124-0.4554.hdf5
#
# Epoch 00125: val_loss improved from 0.45541 to 0.45426, saving model to ./model/best125-0.4543.hdf5
#
# Epoch 00126: val_loss improved from 0.45426 to 0.45285, saving model to ./model/best126-0.4529.hdf5
#
# Epoch 00127: val_loss improved from 0.45285 to 0.45155, saving model to ./model/best127-0.4516.hdf5
#
# Epoch 00128: val_loss improved from 0.45155 to 0.45031, saving model to ./model/best128-0.4503.hdf5
#
# Epoch 00129: val_loss improved from 0.45031 to 0.44910, saving model to ./model/best129-0.4491.hdf5
#
# Epoch 00130: val_loss improved from 0.44910 to 0.44804, saving model to ./model/best130-0.4480.hdf5
#
# Epoch 00131: val_loss improved from 0.44804 to 0.44683, saving model to ./model/best131-0.4468.hdf5
#
# Epoch 00132: val_loss improved from 0.44683 to 0.44547, saving model to ./model/best132-0.4455.hdf5
#
# Epoch 00133: val_loss improved from 0.44547 to 0.44416, saving model to ./model/best133-0.4442.hdf5
#
# Epoch 00134: val_loss improved from 0.44416 to 0.44311, saving model to ./model/best134-0.4431.hdf5
#
# Epoch 00135: val_loss improved from 0.44311 to 0.44227, saving model to ./model/best135-0.4423.hdf5
#
# Epoch 00136: val_loss improved from 0.44227 to 0.44148, saving model to ./model/best136-0.4415.hdf5
#
# Epoch 00137: val_loss improved from 0.44148 to 0.44061, saving model to ./model/best137-0.4406.hdf5
#
# Epoch 00138: val_loss improved from 0.44061 to 0.43966, saving model to ./model/best138-0.4397.hdf5
#
# Epoch 00139: val_loss improved from 0.43966 to 0.43866, saving model to ./model/best139-0.4387.hdf5
#
# Epoch 00140: val_loss improved from 0.43866 to 0.43765, saving model to ./model/best140-0.4376.hdf5
#
# Epoch 00141: val_loss improved from 0.43765 to 0.43679, saving model to ./model/best141-0.4368.hdf5
#
# Epoch 00142: val_loss improved from 0.43679 to 0.43601, saving model to ./model/best142-0.4360.hdf5
#
# Epoch 00143: val_loss improved from 0.43601 to 0.43524, saving model to ./model/best143-0.4352.hdf5
#
# Epoch 00144: val_loss improved from 0.43524 to 0.43437, saving model to ./model/best144-0.4344.hdf5
#
# Epoch 00145: val_loss improved from 0.43437 to 0.43345, saving model to ./model/best145-0.4334.hdf5
#
# Epoch 00146: val_loss improved from 0.43345 to 0.43247, saving model to ./model/best146-0.4325.hdf5
#
# Epoch 00147: val_loss improved from 0.43247 to 0.43147, saving model to ./model/best147-0.4315.hdf5
#
# Epoch 00148: val_loss improved from 0.43147 to 0.43054, saving model to ./model/best148-0.4305.hdf5
#
# Epoch 00149: val_loss improved from 0.43054 to 0.42962, saving model to ./model/best149-0.4296.hdf5
#
# Epoch 00150: val_loss improved from 0.42962 to 0.42874, saving model to ./model/best150-0.4287.hdf5
#
# Epoch 00151: val_loss improved from 0.42874 to 0.42797, saving model to ./model/best151-0.4280.hdf5
#
# Epoch 00152: val_loss improved from 0.42797 to 0.42740, saving model to ./model/best152-0.4274.hdf5
#
# Epoch 00153: val_loss improved from 0.42740 to 0.42696, saving model to ./model/best153-0.4270.hdf5
#
# Epoch 00154: val_loss improved from 0.42696 to 0.42646, saving model to ./model/best154-0.4265.hdf5
#
# Epoch 00155: val_loss improved from 0.42646 to 0.42579, saving model to ./model/best155-0.4258.hdf5
#
# Epoch 00156: val_loss improved from 0.42579 to 0.42497, saving model to ./model/best156-0.4250.hdf5
#
# Epoch 00157: val_loss improved from 0.42497 to 0.42411, saving model to ./model/best157-0.4241.hdf5
#
# Epoch 00158: val_loss improved from 0.42411 to 0.42345, saving model to ./model/best158-0.4235.hdf5
#
# Epoch 00159: val_loss improved from 0.42345 to 0.42301, saving model to ./model/best159-0.4230.hdf5
#
# Epoch 00160: val_loss improved from 0.42301 to 0.42255, saving model to ./model/best160-0.4225.hdf5
#
# Epoch 00161: val_loss improved from 0.42255 to 0.42193, saving model to ./model/best161-0.4219.hdf5
#
# Epoch 00162: val_loss improved from 0.42193 to 0.42117, saving model to ./model/best162-0.4212.hdf5
#
# Epoch 00163: val_loss improved from 0.42117 to 0.42046, saving model to ./model/best163-0.4205.hdf5
#
# Epoch 00164: val_loss improved from 0.42046 to 0.41987, saving model to ./model/best164-0.4199.hdf5
#
# Epoch 00165: val_loss improved from 0.41987 to 0.41941, saving model to ./model/best165-0.4194.hdf5
#
# Epoch 00166: val_loss improved from 0.41941 to 0.41901, saving model to ./model/best166-0.4190.hdf5
#
# Epoch 00167: val_loss improved from 0.41901 to 0.41847, saving model to ./model/best167-0.4185.hdf5
#
# Epoch 00168: val_loss improved from 0.41847 to 0.41765, saving model to ./model/best168-0.4177.hdf5
#
# Epoch 00169: val_loss improved from 0.41765 to 0.41663, saving model to ./model/best169-0.4166.hdf5
#
# Epoch 00170: val_loss improved from 0.41663 to 0.41547, saving model to ./model/best170-0.4155.hdf5
#
# Epoch 00171: val_loss improved from 0.41547 to 0.41450, saving model to ./model/best171-0.4145.hdf5
#
# Epoch 00172: val_loss improved from 0.41450 to 0.41377, saving model to ./model/best172-0.4138.hdf5
#
# Epoch 00173: val_loss improved from 0.41377 to 0.41313, saving model to ./model/best173-0.4131.hdf5
#
# Epoch 00174: val_loss improved from 0.41313 to 0.41237, saving model to ./model/best174-0.4124.hdf5
#
# Epoch 00175: val_loss improved from 0.41237 to 0.41150, saving model to ./model/best175-0.4115.hdf5
#
# Epoch 00176: val_loss improved from 0.41150 to 0.41058, saving model to ./model/best176-0.4106.hdf5
#
# Epoch 00177: val_loss improved from 0.41058 to 0.40981, saving model to ./model/best177-0.4098.hdf5
#
# Epoch 00178: val_loss improved from 0.40981 to 0.40897, saving model to ./model/best178-0.4090.hdf5
#
# Epoch 00179: val_loss improved from 0.40897 to 0.40803, saving model to ./model/best179-0.4080.hdf5
#
# Epoch 00180: val_loss improved from 0.40803 to 0.40692, saving model to ./model/best180-0.4069.hdf5
#
# Epoch 00181: val_loss improved from 0.40692 to 0.40601, saving model to ./model/best181-0.4060.hdf5
#
# Epoch 00182: val_loss improved from 0.40601 to 0.40524, saving model to ./model/best182-0.4052.hdf5
#
# Epoch 00183: val_loss improved from 0.40524 to 0.40434, saving model to ./model/best183-0.4043.hdf5
#
# Epoch 00184: val_loss improved from 0.40434 to 0.40329, saving model to ./model/best184-0.4033.hdf5
#
# Epoch 00185: val_loss improved from 0.40329 to 0.40204, saving model to ./model/best185-0.4020.hdf5
#
# Epoch 00186: val_loss improved from 0.40204 to 0.40078, saving model to ./model/best186-0.4008.hdf5
#
# Epoch 00187: val_loss improved from 0.40078 to 0.39994, saving model to ./model/best187-0.3999.hdf5
#
# Epoch 00188: val_loss improved from 0.39994 to 0.39935, saving model to ./model/best188-0.3993.hdf5
#
# Epoch 00189: val_loss improved from 0.39935 to 0.39889, saving model to ./model/best189-0.3989.hdf5
#
# Epoch 00190: val_loss improved from 0.39889 to 0.39802, saving model to ./model/best190-0.3980.hdf5
#
# Epoch 00191: val_loss improved from 0.39802 to 0.39691, saving model to ./model/best191-0.3969.hdf5
#
# Epoch 00192: val_loss improved from 0.39691 to 0.39617, saving model to ./model/best192-0.3962.hdf5
#
# Epoch 00193: val_loss improved from 0.39617 to 0.39577, saving model to ./model/best193-0.3958.hdf5
#
# Epoch 00194: val_loss improved from 0.39577 to 0.39532, saving model to ./model/best194-0.3953.hdf5
#
# Epoch 00195: val_loss improved from 0.39532 to 0.39450, saving model to ./model/best195-0.3945.hdf5
#
# Epoch 00196: val_loss improved from 0.39450 to 0.39338, saving model to ./model/best196-0.3934.hdf5
#
# Epoch 00197: val_loss improved from 0.39338 to 0.39268, saving model to ./model/best197-0.3927.hdf5
#
# Epoch 00198: val_loss improved from 0.39268 to 0.39241, saving model to ./model/best198-0.3924.hdf5
#
# Epoch 00199: val_loss did not improve from 0.39241
#
# Epoch 00200: val_loss improved from 0.39241 to 0.39204, saving model to ./model/best200-0.3920.hdf5
#
# Epoch 00201: val_loss improved from 0.39204 to 0.39109, saving model to ./model/best201-0.3911.hdf5
#
# Epoch 00202: val_loss improved from 0.39109 to 0.39048, saving model to ./model/best202-0.3905.hdf5
#
# Epoch 00203: val_loss improved from 0.39048 to 0.39025, saving model to ./model/best203-0.3902.hdf5
#
# Epoch 00204: val_loss improved from 0.39025 to 0.39006, saving model to ./model/best204-0.3901.hdf5
#
# Epoch 00205: val_loss improved from 0.39006 to 0.38943, saving model to ./model/best205-0.3894.hdf5
#
# Epoch 00206: val_loss improved from 0.38943 to 0.38849, saving model to ./model/best206-0.3885.hdf5
#
# Epoch 00207: val_loss improved from 0.38849 to 0.38808, saving model to ./model/best207-0.3881.hdf5
#
# Epoch 00208: val_loss improved from 0.38808 to 0.38793, saving model to ./model/best208-0.3879.hdf5
#
# Epoch 00209: val_loss improved from 0.38793 to 0.38751, saving model to ./model/best209-0.3875.hdf5
#
# Epoch 00210: val_loss improved from 0.38751 to 0.38649, saving model to ./model/best210-0.3865.hdf5
#
# Epoch 00211: val_loss improved from 0.38649 to 0.38570, saving model to ./model/best211-0.3857.hdf5
#
# Epoch 00212: val_loss improved from 0.38570 to 0.38555, saving model to ./model/best212-0.3856.hdf5
#
# Epoch 00213: val_loss did not improve from 0.38555
#
# Epoch 00214: val_loss did not improve from 0.38555
#
# Epoch 00215: val_loss improved from 0.38555 to 0.38484, saving model to ./model/best215-0.3848.hdf5
#
# Epoch 00216: val_loss improved from 0.38484 to 0.38390, saving model to ./model/best216-0.3839.hdf5
#
# Epoch 00217: val_loss improved from 0.38390 to 0.38332, saving model to ./model/best217-0.3833.hdf5
#
# Epoch 00218: val_loss improved from 0.38332 to 0.38319, saving model to ./model/best218-0.3832.hdf5
#
# Epoch 00219: val_loss improved from 0.38319 to 0.38299, saving model to ./model/best219-0.3830.hdf5
#
# Epoch 00220: val_loss improved from 0.38299 to 0.38255, saving model to ./model/best220-0.3826.hdf5
#
# Epoch 00221: val_loss improved from 0.38255 to 0.38188, saving model to ./model/best221-0.3819.hdf5
#
# Epoch 00222: val_loss improved from 0.38188 to 0.38161, saving model to ./model/best222-0.3816.hdf5
#
# Epoch 00223: val_loss did not improve from 0.38161
#
# Epoch 00224: val_loss did not improve from 0.38161
#
# Epoch 00225: val_loss did not improve from 0.38161
#
# Epoch 00226: val_loss did not improve from 0.38161
#
# Epoch 00227: val_loss did not improve from 0.38161
#
# Epoch 00228: val_loss did not improve from 0.38161
#
# Epoch 00229: val_loss did not improve from 0.38161
#
# Epoch 00230: val_loss improved from 0.38161 to 0.38134, saving model to ./model/best230-0.3813.hdf5
#
# Epoch 00231: val_loss improved from 0.38134 to 0.38110, saving model to ./model/best231-0.3811.hdf5
#
# Epoch 00232: val_loss did not improve from 0.38110
#
# Epoch 00233: val_loss did not improve from 0.38110
#
# Epoch 00234: val_loss improved from 0.38110 to 0.38021, saving model to ./model/best234-0.3802.hdf5
#
# Epoch 00235: val_loss improved from 0.38021 to 0.37949, saving model to ./model/best235-0.3795.hdf5
#
# Epoch 00236: val_loss improved from 0.37949 to 0.37936, saving model to ./model/best236-0.3794.hdf5
#
# Epoch 00237: val_loss improved from 0.37936 to 0.37915, saving model to ./model/best237-0.3791.hdf5
#
# Epoch 00238: val_loss improved from 0.37915 to 0.37880, saving model to ./model/best238-0.3788.hdf5
#
# Epoch 00239: val_loss improved from 0.37880 to 0.37879, saving model to ./model/best239-0.3788.hdf5
#
# Epoch 00240: val_loss did not improve from 0.37879
#
# Epoch 00241: val_loss improved from 0.37879 to 0.37843, saving model to ./model/best241-0.3784.hdf5
#
# Epoch 00242: val_loss improved from 0.37843 to 0.37811, saving model to ./model/best242-0.3781.hdf5
#
# Epoch 00243: val_loss did not improve from 0.37811
#
# Epoch 00244: val_loss did not improve from 0.37811
#
# Epoch 00245: val_loss improved from 0.37811 to 0.37778, saving model to ./model/best245-0.3778.hdf5
#
# Epoch 00246: val_loss improved from 0.37778 to 0.37756, saving model to ./model/best246-0.3776.hdf5
#
# Epoch 00247: val_loss improved from 0.37756 to 0.37750, saving model to ./model/best247-0.3775.hdf5
#
# Epoch 00248: val_loss improved from 0.37750 to 0.37696, saving model to ./model/best248-0.3770.hdf5
#
# Epoch 00249: val_loss improved from 0.37696 to 0.37647, saving model to ./model/best249-0.3765.hdf5
#
# Epoch 00250: val_loss did not improve from 0.37647
#
# Epoch 00251: val_loss did not improve from 0.37647
#
# Epoch 00252: val_loss did not improve from 0.37647
#
# Epoch 00253: val_loss improved from 0.37647 to 0.37625, saving model to ./model/best253-0.3763.hdf5
#
# Epoch 00254: val_loss improved from 0.37625 to 0.37606, saving model to ./model/best254-0.3761.hdf5
#
# Epoch 00255: val_loss did not improve from 0.37606
#
# Epoch 00256: val_loss did not improve from 0.37606
#
# Epoch 00257: val_loss did not improve from 0.37606
#
# Epoch 00258: val_loss did not improve from 0.37606
#
# Epoch 00259: val_loss improved from 0.37606 to 0.37561, saving model to ./model/best259-0.3756.hdf5
#
# Epoch 00260: val_loss did not improve from 0.37561
#
# Epoch 00261: val_loss did not improve from 0.37561
#
# Epoch 00262: val_loss improved from 0.37561 to 0.37511, saving model to ./model/best262-0.3751.hdf5
#
# Epoch 00263: val_loss did not improve from 0.37511
#
# Epoch 00264: val_loss did not improve from 0.37511
#
# Epoch 00265: val_loss did not improve from 0.37511
#
# Epoch 00266: val_loss improved from 0.37511 to 0.37493, saving model to ./model/best266-0.3749.hdf5
#
# Epoch 00267: val_loss improved from 0.37493 to 0.37486, saving model to ./model/best267-0.3749.hdf5
#
# Epoch 00268: val_loss did not improve from 0.37486
#
# Epoch 00269: val_loss did not improve from 0.37486
#
# Epoch 00270: val_loss did not improve from 0.37486
#
# Epoch 00271: val_loss did not improve from 0.37486
#
# Epoch 00272: val_loss improved from 0.37486 to 0.37426, saving model to ./model/best272-0.3743.hdf5
#
# Epoch 00273: val_loss did not improve from 0.37426
#
# Epoch 00274: val_loss did not improve from 0.37426
#
# Epoch 00275: val_loss did not improve from 0.37426
#
# Epoch 00276: val_loss did not improve from 0.37426
#
# Epoch 00277: val_loss improved from 0.37426 to 0.37409, saving model to ./model/best277-0.3741.hdf5
#
# Epoch 00278: val_loss improved from 0.37409 to 0.37394, saving model to ./model/best278-0.3739.hdf5
#
# Epoch 00279: val_loss did not improve from 0.37394
#
# Epoch 00280: val_loss did not improve from 0.37394
#
# Epoch 00281: val_loss did not improve from 0.37394
#
# Epoch 00282: val_loss did not improve from 0.37394
#
# Epoch 00283: val_loss did not improve from 0.37394
#
# Epoch 00284: val_loss did not improve from 0.37394
#
# Epoch 00285: val_loss did not improve from 0.37394
#
# Epoch 00286: val_loss did not improve from 0.37394
#
# Epoch 00287: val_loss did not improve from 0.37394
#
# Epoch 00288: val_loss did not improve from 0.37394
#
# Epoch 00289: val_loss did not improve from 0.37394
#
# Epoch 00290: val_loss did not improve from 0.37394
#
# Epoch 00291: val_loss did not improve from 0.37394
#
# Epoch 00292: val_loss did not improve from 0.37394
#
# Epoch 00293: val_loss did not improve from 0.37394
#
# Epoch 00294: val_loss did not improve from 0.37394
#
# Epoch 00295: val_loss did not improve from 0.37394
#
# Epoch 00296: val_loss did not improve from 0.37394
#
# Epoch 00297: val_loss did not improve from 0.37394
#
# Epoch 00298: val_loss did not improve from 0.37394
#
# Epoch 00299: val_loss did not improve from 0.37394
#
# Epoch 00300: val_loss did not improve from 0.37394
#
# Epoch 00301: val_loss did not improve from 0.37394
#
# Epoch 00302: val_loss did not improve from 0.37394
#
# Epoch 00303: val_loss did not improve from 0.37394
#
# Epoch 00304: val_loss improved from 0.37394 to 0.37374, saving model to ./model/best304-0.3737.hdf5
#
# Epoch 00305: val_loss improved from 0.37374 to 0.37373, saving model to ./model/best305-0.3737.hdf5
#
# Epoch 00306: val_loss did not improve from 0.37373
#
# Epoch 00307: val_loss did not improve from 0.37373
#
# Epoch 00308: val_loss did not improve from 0.37373
#
# Epoch 00309: val_loss did not improve from 0.37373
#
# Epoch 00310: val_loss did not improve from 0.37373
#
# Epoch 00311: val_loss did not improve from 0.37373
#
# Epoch 00312: val_loss did not improve from 0.37373
#
# Epoch 00313: val_loss did not improve from 0.37373
#
# Epoch 00314: val_loss did not improve from 0.37373
#
# Epoch 00315: val_loss did not improve from 0.37373
#
# Epoch 00316: val_loss did not improve from 0.37373
#
# Epoch 00317: val_loss did not improve from 0.37373
#
# Epoch 00318: val_loss did not improve from 0.37373
#
# Epoch 00319: val_loss did not improve from 0.37373
#
# Epoch 00320: val_loss did not improve from 0.37373
#
# Epoch 00321: val_loss did not improve from 0.37373
#
# Epoch 00322: val_loss did not improve from 0.37373
#
# Epoch 00323: val_loss did not improve from 0.37373
#
# Epoch 00324: val_loss did not improve from 0.37373
#
# Epoch 00325: val_loss did not improve from 0.37373
#
# Epoch 00326: val_loss did not improve from 0.37373
#
# Epoch 00327: val_loss did not improve from 0.37373
#
# Epoch 00328: val_loss did not improve from 0.37373
#
# Epoch 00329: val_loss did not improve from 0.37373
#
# Epoch 00330: val_loss did not improve from 0.37373
#
# Epoch 00331: val_loss did not improve from 0.37373
#
# Epoch 00332: val_loss did not improve from 0.37373
#
# Epoch 00333: val_loss did not improve from 0.37373
#
# Epoch 00334: val_loss did not improve from 0.37373
#
# Epoch 00335: val_loss did not improve from 0.37373

# %%
from tensorflow.keras.models import load_model
best_model = load_model('./model/best305-0.3737.hdf5')
acc = best_model.evaluate(X_test, y_test)
print(f'Accuracy: {acc[1]:.4f}')
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4524 - accuracy: 0.8077
# Accuracy: 0.8077

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
y_vloss = history.history['val_loss']
y_acc = history.history['accuracy']
y_vacc = history.history['val_accuracy']
y_loss = history.history['loss']

x_len = np.arange(len(y_acc))
plt.figure(figsize=(12, 8))
plt.plot(x_len, y_loss, "-o", c='red', markersize=2, label='loss')
plt.plot(x_len, y_vacc, "-o", c='blue', markersize=2, label='val_accuracy')
plt.plot(x_len, y_vloss, "-o", c='orange', markersize=2, label='val_loss')
plt.plot(x_len, y_acc, "-o", c='green', markersize=2, label='accuracy')
plt.legend()
plt.show()
