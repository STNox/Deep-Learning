# %% [markdown]
# # Cifar-10 이미지 분류

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import os
import numpy as np

# %%
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
BATCH_SIZE = 32
NUM_CLASSES = 10
EPOCHS = 100
DATA_AUGMENTATION = True
NUM_PREDICTION = 20
SAVE_DIR = os.path.join(os.getcwd(), 'model')
MODEL_NAME = 'keras_cifar10_trained_model.h5'

# %%
(x_train, y_train0), (x_test, y_test0) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
y_test0[0]
# Out:
# array([3], dtype=uint8)

# %% [markdown]
# ### 데이터 확인

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplot(141)
plt.imshow(x_train[0], interpolation='bicubic')
plt.grid(False)
plt.subplot(142)
plt.imshow(x_train[4], interpolation='bicubic')
plt.grid(False)
plt.subplot(143)
plt.imshow(x_train[8], interpolation='bicubic')
plt.grid(False)
plt.subplot(144)
plt.imshow(x_train[12], interpolation='bicubic')
plt.grid(False)
plt.show()

# %%
# 자료형 실수 변환, 정규화
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
# One hot encoding
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train0, NUM_CLASSES)
y_test = to_categorical(y_test0, NUM_CLASSES)
y_train.shape, y_test.shape
# Out:
# ((50000, 10), (10000, 10))

# %% [markdown]
# ### 모델 정의/설정/학습

# %%
model = Sequential([
                    Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:], activation='relu'),
                    Conv2D(32, (3, 3), activation='relu'),
                    MaxPooling2D(pool_size=(2, 2)),
                    Dropout(0.25),
                    Conv2D(64, (3, 3), padding='same', activation='relu'),
                    Conv2D(64, (3, 3), activation='relu'),
                    MaxPooling2D(pool_size=(2, 2)),
                    Dropout(0.25),
                    Flatten(),
                    Dense(512, activation='relu'),
                    Dropout(0.5),
                    Dense(NUM_CLASSES, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
opt = RMSprop(learning_rate=0.0001, decay=1e-6)

# %%
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
modelpath = 'model/cifar10-cnn-{epoch:02d}-{val_loss:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=[checkpointer, early_stopping], validation_split=0.2, shuffle=True)
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - 9s 5ms/step - loss: 2.0561 - accuracy: 0.2361 - val_loss: 1.6234 - val_accuracy: 0.4234
#
# Epoch 00001: val_loss improved from inf to 1.62342, saving model to model/cifar10-cnn-01-1.6234.hdf5
# Epoch 2/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.6160 - accuracy: 0.4061 - val_loss: 1.4911 - val_accuracy: 0.4615
#
# Epoch 00002: val_loss improved from 1.62342 to 1.49111, saving model to model/cifar10-cnn-02-1.4911.hdf5
# Epoch 3/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4566 - accuracy: 0.4686 - val_loss: 1.3644 - val_accuracy: 0.5213
#
# Epoch 00003: val_loss improved from 1.49111 to 1.36438, saving model to model/cifar10-cnn-03-1.3644.hdf5
# Epoch 4/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3631 - accuracy: 0.5087 - val_loss: 1.2404 - val_accuracy: 0.5673
#
# Epoch 00004: val_loss improved from 1.36438 to 1.24041, saving model to model/cifar10-cnn-04-1.2404.hdf5
# Epoch 5/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2921 - accuracy: 0.5379 - val_loss: 1.2618 - val_accuracy: 0.5582
#
# Epoch 00005: val_loss did not improve from 1.24041
# Epoch 6/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2239 - accuracy: 0.5705 - val_loss: 1.1592 - val_accuracy: 0.5931
#
# Epoch 00006: val_loss improved from 1.24041 to 1.15922, saving model to model/cifar10-cnn-06-1.1592.hdf5
# Epoch 7/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1521 - accuracy: 0.5933 - val_loss: 1.0643 - val_accuracy: 0.6302
#
# Epoch 00007: val_loss improved from 1.15922 to 1.06432, saving model to model/cifar10-cnn-07-1.0643.hdf5
# Epoch 8/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1130 - accuracy: 0.6101 - val_loss: 1.0273 - val_accuracy: 0.6425
#
# Epoch 00008: val_loss improved from 1.06432 to 1.02727, saving model to model/cifar10-cnn-08-1.0273.hdf5
# Epoch 9/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0633 - accuracy: 0.6255 - val_loss: 1.0122 - val_accuracy: 0.6469
#
# Epoch 00009: val_loss improved from 1.02727 to 1.01216, saving model to model/cifar10-cnn-09-1.0122.hdf5
# Epoch 10/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0254 - accuracy: 0.6422 - val_loss: 0.9338 - val_accuracy: 0.6769
#
# Epoch 00010: val_loss improved from 1.01216 to 0.93378, saving model to model/cifar10-cnn-10-0.9338.hdf5
# Epoch 11/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9807 - accuracy: 0.6563 - val_loss: 0.9323 - val_accuracy: 0.6703
#
# Epoch 00011: val_loss improved from 0.93378 to 0.93226, saving model to model/cifar10-cnn-11-0.9323.hdf5
# Epoch 12/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9515 - accuracy: 0.6677 - val_loss: 0.8884 - val_accuracy: 0.6940
#
# Epoch 00012: val_loss improved from 0.93226 to 0.88844, saving model to model/cifar10-cnn-12-0.8884.hdf5
# Epoch 13/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9345 - accuracy: 0.6732 - val_loss: 0.9053 - val_accuracy: 0.6880
#
# Epoch 00013: val_loss did not improve from 0.88844
# Epoch 14/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9060 - accuracy: 0.6869 - val_loss: 0.8758 - val_accuracy: 0.6930
#
# Epoch 00014: val_loss improved from 0.88844 to 0.87580, saving model to model/cifar10-cnn-14-0.8758.hdf5
# Epoch 15/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8804 - accuracy: 0.6930 - val_loss: 0.8558 - val_accuracy: 0.7010
#
# Epoch 00015: val_loss improved from 0.87580 to 0.85579, saving model to model/cifar10-cnn-15-0.8558.hdf5
# Epoch 16/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8608 - accuracy: 0.7023 - val_loss: 0.8257 - val_accuracy: 0.7102
#
# Epoch 00016: val_loss improved from 0.85579 to 0.82571, saving model to model/cifar10-cnn-16-0.8257.hdf5
# Epoch 17/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8339 - accuracy: 0.7118 - val_loss: 0.7966 - val_accuracy: 0.7241
#
# Epoch 00017: val_loss improved from 0.82571 to 0.79665, saving model to model/cifar10-cnn-17-0.7966.hdf5
# Epoch 18/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8103 - accuracy: 0.7187 - val_loss: 0.7944 - val_accuracy: 0.7237
#
# Epoch 00018: val_loss improved from 0.79665 to 0.79435, saving model to model/cifar10-cnn-18-0.7944.hdf5
# Epoch 19/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8110 - accuracy: 0.7190 - val_loss: 0.7871 - val_accuracy: 0.7278
#
# Epoch 00019: val_loss improved from 0.79435 to 0.78708, saving model to model/cifar10-cnn-19-0.7871.hdf5
# Epoch 20/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7787 - accuracy: 0.7306 - val_loss: 0.7604 - val_accuracy: 0.7403
#
# Epoch 00020: val_loss improved from 0.78708 to 0.76041, saving model to model/cifar10-cnn-20-0.7604.hdf5
# Epoch 21/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7771 - accuracy: 0.7292 - val_loss: 0.7714 - val_accuracy: 0.7355
#
# Epoch 00021: val_loss did not improve from 0.76041
# Epoch 22/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7665 - accuracy: 0.7348 - val_loss: 0.7349 - val_accuracy: 0.7463
#
# Epoch 00022: val_loss improved from 0.76041 to 0.73487, saving model to model/cifar10-cnn-22-0.7349.hdf5
# Epoch 23/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7479 - accuracy: 0.7402 - val_loss: 0.7377 - val_accuracy: 0.7457
#
# Epoch 00023: val_loss did not improve from 0.73487
# Epoch 24/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7389 - accuracy: 0.7426 - val_loss: 0.7393 - val_accuracy: 0.7491
#
# Epoch 00024: val_loss did not improve from 0.73487
# Epoch 25/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7259 - accuracy: 0.7513 - val_loss: 0.7166 - val_accuracy: 0.7562
#
# Epoch 00025: val_loss improved from 0.73487 to 0.71657, saving model to model/cifar10-cnn-25-0.7166.hdf5
# Epoch 26/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7137 - accuracy: 0.7538 - val_loss: 0.7244 - val_accuracy: 0.7562
#
# Epoch 00026: val_loss did not improve from 0.71657
# Epoch 27/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7210 - accuracy: 0.7533 - val_loss: 0.7045 - val_accuracy: 0.7568
#
# Epoch 00027: val_loss improved from 0.71657 to 0.70449, saving model to model/cifar10-cnn-27-0.7045.hdf5
# Epoch 28/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7042 - accuracy: 0.7592 - val_loss: 0.7087 - val_accuracy: 0.7550
#
# Epoch 00028: val_loss did not improve from 0.70449
# Epoch 29/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7008 - accuracy: 0.7617 - val_loss: 0.6977 - val_accuracy: 0.7595
#
# Epoch 00029: val_loss improved from 0.70449 to 0.69775, saving model to model/cifar10-cnn-29-0.6977.hdf5
# Epoch 30/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6910 - accuracy: 0.7654 - val_loss: 0.7155 - val_accuracy: 0.7589
#
# Epoch 00030: val_loss did not improve from 0.69775
# Epoch 31/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6958 - accuracy: 0.7656 - val_loss: 0.7020 - val_accuracy: 0.7623
#
# Epoch 00031: val_loss did not improve from 0.69775
# Epoch 32/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6823 - accuracy: 0.7652 - val_loss: 0.7115 - val_accuracy: 0.7635
#
# Epoch 00032: val_loss did not improve from 0.69775
# Epoch 33/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6822 - accuracy: 0.7668 - val_loss: 0.7061 - val_accuracy: 0.7591
#
# Epoch 00033: val_loss did not improve from 0.69775
# Epoch 34/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6813 - accuracy: 0.7684 - val_loss: 0.6876 - val_accuracy: 0.7650
#
# Epoch 00034: val_loss improved from 0.69775 to 0.68764, saving model to model/cifar10-cnn-34-0.6876.hdf5
# Epoch 35/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6764 - accuracy: 0.7691 - val_loss: 0.6782 - val_accuracy: 0.7678
#
# Epoch 00035: val_loss improved from 0.68764 to 0.67823, saving model to model/cifar10-cnn-35-0.6782.hdf5
# Epoch 36/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6672 - accuracy: 0.7763 - val_loss: 0.6774 - val_accuracy: 0.7709
#
# Epoch 00036: val_loss improved from 0.67823 to 0.67741, saving model to model/cifar10-cnn-36-0.6774.hdf5
# Epoch 37/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6643 - accuracy: 0.7748 - val_loss: 0.6964 - val_accuracy: 0.7643
#
# Epoch 00037: val_loss did not improve from 0.67741
# Epoch 38/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6687 - accuracy: 0.7710 - val_loss: 0.6915 - val_accuracy: 0.7675
#
# Epoch 00038: val_loss did not improve from 0.67741
# Epoch 39/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6545 - accuracy: 0.7779 - val_loss: 0.6778 - val_accuracy: 0.7740
#
# Epoch 00039: val_loss did not improve from 0.67741
# Epoch 40/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6571 - accuracy: 0.7774 - val_loss: 0.6898 - val_accuracy: 0.7742
#
# Epoch 00040: val_loss did not improve from 0.67741
# Epoch 41/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6674 - accuracy: 0.7756 - val_loss: 0.6863 - val_accuracy: 0.7740
#
# Epoch 00041: val_loss did not improve from 0.67741
# Epoch 42/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6584 - accuracy: 0.7794 - val_loss: 0.7022 - val_accuracy: 0.7715
#
# Epoch 00042: val_loss did not improve from 0.67741
# Epoch 43/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6536 - accuracy: 0.7780 - val_loss: 0.6663 - val_accuracy: 0.7740
#
# Epoch 00043: val_loss improved from 0.67741 to 0.66632, saving model to model/cifar10-cnn-43-0.6663.hdf5
# Epoch 44/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6555 - accuracy: 0.7766 - val_loss: 0.7377 - val_accuracy: 0.7583
#
# Epoch 00044: val_loss did not improve from 0.66632
# Epoch 45/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6508 - accuracy: 0.7811 - val_loss: 0.6905 - val_accuracy: 0.7738
#
# Epoch 00045: val_loss did not improve from 0.66632
# Epoch 46/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6380 - accuracy: 0.7849 - val_loss: 0.7101 - val_accuracy: 0.7617
#
# Epoch 00046: val_loss did not improve from 0.66632
# Epoch 47/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6445 - accuracy: 0.7831 - val_loss: 0.6832 - val_accuracy: 0.7705
#
# Epoch 00047: val_loss did not improve from 0.66632
# Epoch 48/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6396 - accuracy: 0.7847 - val_loss: 0.6620 - val_accuracy: 0.7769
#
# Epoch 00048: val_loss improved from 0.66632 to 0.66204, saving model to model/cifar10-cnn-48-0.6620.hdf5
# Epoch 49/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6319 - accuracy: 0.7867 - val_loss: 0.6683 - val_accuracy: 0.7774
#
# Epoch 00049: val_loss did not improve from 0.66204
# Epoch 50/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6402 - accuracy: 0.7887 - val_loss: 0.6509 - val_accuracy: 0.7868
#
# Epoch 00050: val_loss improved from 0.66204 to 0.65090, saving model to model/cifar10-cnn-50-0.6509.hdf5
# Epoch 51/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6358 - accuracy: 0.7860 - val_loss: 0.6708 - val_accuracy: 0.7801
#
# Epoch 00051: val_loss did not improve from 0.65090
# Epoch 52/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6257 - accuracy: 0.7923 - val_loss: 0.6821 - val_accuracy: 0.7783
#
# Epoch 00052: val_loss did not improve from 0.65090
# Epoch 53/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6235 - accuracy: 0.7941 - val_loss: 0.6906 - val_accuracy: 0.7743
#
# Epoch 00053: val_loss did not improve from 0.65090
# Epoch 54/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6326 - accuracy: 0.7886 - val_loss: 0.6510 - val_accuracy: 0.7857
#
# Epoch 00054: val_loss did not improve from 0.65090
# Epoch 55/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6431 - accuracy: 0.7852 - val_loss: 0.6659 - val_accuracy: 0.7786
#
# Epoch 00055: val_loss did not improve from 0.65090
# Epoch 56/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6161 - accuracy: 0.7948 - val_loss: 0.6688 - val_accuracy: 0.7790
#
# Epoch 00056: val_loss did not improve from 0.65090
# Epoch 57/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6211 - accuracy: 0.7934 - val_loss: 0.6746 - val_accuracy: 0.7815
#
# Epoch 00057: val_loss did not improve from 0.65090
# Epoch 58/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6270 - accuracy: 0.7892 - val_loss: 0.6445 - val_accuracy: 0.7836
#
# Epoch 00058: val_loss improved from 0.65090 to 0.64453, saving model to model/cifar10-cnn-58-0.6445.hdf5
# Epoch 59/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6212 - accuracy: 0.7936 - val_loss: 0.6642 - val_accuracy: 0.7839
#
# Epoch 00059: val_loss did not improve from 0.64453
# Epoch 60/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6324 - accuracy: 0.7883 - val_loss: 0.6464 - val_accuracy: 0.7877
#
# Epoch 00060: val_loss did not improve from 0.64453
# Epoch 61/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6159 - accuracy: 0.7925 - val_loss: 0.6970 - val_accuracy: 0.7755
#
# Epoch 00061: val_loss did not improve from 0.64453
# Epoch 62/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6095 - accuracy: 0.7976 - val_loss: 0.6526 - val_accuracy: 0.7823
#
# Epoch 00062: val_loss did not improve from 0.64453
# Epoch 63/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6199 - accuracy: 0.7922 - val_loss: 0.7191 - val_accuracy: 0.7739
#
# Epoch 00063: val_loss did not improve from 0.64453
# Epoch 64/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6111 - accuracy: 0.7969 - val_loss: 0.6640 - val_accuracy: 0.7834
#
# Epoch 00064: val_loss did not improve from 0.64453
# Epoch 65/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6169 - accuracy: 0.7928 - val_loss: 0.6470 - val_accuracy: 0.7837
#
# Epoch 00065: val_loss did not improve from 0.64453
# Epoch 66/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6090 - accuracy: 0.7929 - val_loss: 0.6613 - val_accuracy: 0.7811
#
# Epoch 00066: val_loss did not improve from 0.64453
# Epoch 67/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6107 - accuracy: 0.7978 - val_loss: 0.6854 - val_accuracy: 0.7867
#
# Epoch 00067: val_loss did not improve from 0.64453
# Epoch 68/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6107 - accuracy: 0.7957 - val_loss: 0.6766 - val_accuracy: 0.7792
#
# Epoch 00068: val_loss did not improve from 0.64453

# %%
from tensorflow.keras.models import load_model
best_model = load_model('model/cifar10-cnn-58-0.6445.hdf5')
acc = best_model.evaluate(x_test, y_test, verbose=2)[1]
print(f'Test Accuracy: {acc:.4f}')
# Out:
# 313/313 - 1s - loss: 0.6485 - accuracy: 0.7844
# Test Accuracy: 0.7844

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(1, len(y_loss)+1)
plt.figure(figsize=(8, 6))
plt.plot(x_len, y_vloss, marker='.', c='red', label='Validation_loss')
plt.plot(x_len, y_loss, marker='.', c='blue', label='Trainset_loss')
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
